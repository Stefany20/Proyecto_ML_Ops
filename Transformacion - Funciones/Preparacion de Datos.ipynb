# %% [markdown]
# Preparacion de Datos

# %%
#importamos librerias
import numpy as np
import pandas as pd
import ast
import re

# %%
#cargamos los datos 
data = pd.read_csv("movies_dataset.csv")
data.head()
# Out:
# C:\Users\luisr\AppData\Local\Temp\ipykernel_13072\2627367434.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("movies_dataset.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %% [markdown]
# Los valores nulos de los campos revenue, budget deben ser rellenados por el número 0.

# %%
#reeplazamos los valores nulos por 0

data[["revenue", "budget"]].fillna(0)
# Out:
#            revenue    budget
# 0      373554033.0  30000000
# 1      262797249.0  65000000
# 2              0.0         0
# 3       81452156.0  16000000
# 4       76578911.0         0
# ...            ...       ...
# 45461          0.0         0
# 45462          0.0         0
# 45463          0.0         0
# 45464          0.0         0
# 45465          0.0         0
#
# [45466 rows x 2 columns]

# %% [markdown]
# De haber fechas, deberán tener el formato AAAA-mm-dd, además deberán crear la columna release_year donde extraerán el año de la fecha de estreno.

# %%
#reemplazamos las fechas dejando de lado los errores
data["release_date"] = pd.to_datetime(data["release_date"], format="%Y-%m-%d",errors="coerce")

# %%
#creamos una columna con el año de la fecha de estreno
data["release_year"] = data["release_date"].dt.year

# %%
#cambiamos de nulos a ceros para cambiar el tipo de dato año
data["release_year"].fillna(0)
# Out:
# 0        1995.0
# 1        1995.0
# 2        1995.0
# 3        1995.0
# 4        1995.0
#           ...
# 45461       0.0
# 45462    2011.0
# 45463    2003.0
# 45464    1917.0
# 45465    2017.0
# Name: release_year, Length: 45466, dtype: float64

# %%
# Convierte la columna en entero
data["release_year"] = data["release_year"].astype("Int64")

# %% [markdown]
# Crear la columna con el retorno de inversión, llamada return con los campos revenue y budget, dividiendo estas dos últimas revenue / budget, cuando no hay datos disponibles para calcularlo, deberá tomar el valor 0.

# %%
#cambiamos los null en 0
data["budget"].fillna(0)
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %%
#creamos un for por que hay valores que no se han cambiado a cero
budget = data["budget"] 
for i in range(len(budget)):
    if budget[i] != budget[i]:
        budget[i] = 0
print(budget)
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %%
#lo convertinos a numerico para poder manejarlo
data["budget"] = pd.to_numeric(data["budget"], errors="coerce")

# %%
#creamos la columna
data["return"] = data.apply(lambda row: row["revenue"] / row["budget"] if (row["budget"] != 0 and row["revenue"] != 0) else 0, axis=1)

# %%
data["return"]
# Out:
# 0        12.451801
# 1         4.043035
# 2         0.000000
# 3         5.090760
# 4         0.000000
#            ...
# 45461     0.000000
# 45462     0.000000
# 45463     0.000000
# 45464     0.000000
# 45465     0.000000
# Name: return, Length: 45466, dtype: float64

# %% [markdown]
# Eliminar las columnas que no serán utilizadas, video,imdb_id,adult,original_title,vote_count,poster_path y homepage.

# %%
data = data.drop(["video","imdb_id","adult","original_title","vote_count","poster_path","homepage"], axis=1)

# %% [markdown]
# Algunos campos, como belongs_to_collection, production_companies y otros (ver diccionario de datos) están anidados, esto es o bien tienen un diccionario o una lista como valores en cada fila, ¡deberán desanidarlos para poder y unirlos al dataset de nuevo hacer alguna de las consultas de la API! O bien buscar la manera de acceder a esos datos sin desanidarlos.

# %%
print(data["genres"].unique())
# Out:
# ["[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"
#  "[{'id': 12, 'name': 'Adventure'}, {'id': 14, 'name': 'Fantasy'}, {'id': 10751, 'name': 'Family'}]"
#  "[{'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]" ...
#  "[{'id': 80, 'name': 'Crime'}, {'id': 35, 'name': 'Comedy'}, {'id': 28, 'name': 'Action'}, {'id': 10751, 'name': 'Family'}]"
#  "[{'id': 28, 'name': 'Action'}, {'id': 9648, 'name': 'Mystery'}, {'id': 53, 'name': 'Thriller'}, {'id': 27, 'name': 'Horror'}]"
#  "[{'id': 10751, 'name': 'Family'}, {'id': 16, 'name': 'Animation'}, {'id': 10749, 'name': 'Romance'}, {'id': 35, 'name': 'Comedy'}]"]

# %%
#creamos una funcion que nos permite acceder a name 
def convertir(obj):
    lista = []
    for i in ast.literal_eval(obj):
        lista.append(i['name'])
    return lista

# %%
data["genres"] = data["genres"].apply(convertir)
data.head()
# Out:
#                                belongs_to_collection      budget  \
# 0  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000.0
# 1                                                NaN  65000000.0
# 2  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0.0
# 3                                                NaN  16000000.0
# 4  {'id': 96871, 'name': 'Father of the Bride Col...         0.0
#
#                          genres     id original_language  \
# 0   [Animation, Comedy, Family]    862                en
# 1  [Adventure, Fantasy, Family]   8844                en
# 2             [Romance, Comedy]  15602                en
# 3      [Comedy, Drama, Romance]  31357                en
# 4                      [Comedy]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# ...

# %%
#Creamos una funcion para extraer los valore de una cadena
def extraer_datos(df, columna):
   
    def extraer_valores(valor):
        if isinstance(valor, str):
            # Si es una cadena, extraer los valores con la expresión regular
            pattern = r"'name': '([^']*)'"
            coincidencias = re.findall(pattern, valor)
            return coincidencias
        elif isinstance(valor, list):
            # Si es una lista, extraer los valores de cada elemento de la lista
            valores = []
            for elemento in valor:
                if 'name' in elemento:
                    valores.append(elemento['name'])
            return valores
        elif isinstance(valor, dict):
            # Si es un diccionario, extraer los valores de la clave 'name'
            if 'name' in valor:
                return valor['name']
        return None
    
    # Aplicar la función a la columna y sobrescribir la columna
    df[columna] = df[columna].apply(extraer_valores)
    
    return df

# %% [markdown]
# Aplicar la función para extraer los datos de la columna

# %%
data = extraer_datos(data, 'production_companies')

# %%
data = extraer_datos(data, 'production_countries')
data = extraer_datos(data, 'spoken_languages')

# %%
data.head()
# Out:
#                 belongs_to_collection      budget  \
# 0            ['Toy Story Collection']  30000000.0
# 1                                 NaN  65000000.0
# 2       ['Grumpy Old Men Collection']         0.0
# 3                                 NaN  16000000.0
# 4  ['Father of the Bride Collection']         0.0
#
#                          genres     id original_language  \
# 0   [Animation, Comedy, Family]    862                en
# 1  [Adventure, Fantasy, Family]   8844                en
# 2             [Romance, Comedy]  15602                en
# 3      [Comedy, Drama, Romance]  31357                en
# 4                      [Comedy]  11862                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 2  A family wedding reignites the ancient feud be...    11.7129
# ...

# %%
data1 = pd.read_csv("mi_movies_dataset.csv")
# Out:
# C:\Users\luisr\AppData\Local\Temp\ipykernel_13072\1376273287.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv("mi_movies_dataset.csv")

# %%
data["belongs_to_collection"] = data1["belongs_to_collection"]

# %%
data.to_csv("definido_movies_dataset.csv")
